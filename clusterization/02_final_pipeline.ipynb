# %%
from scipy import sparse
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import os
import seaborn as sns

from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
import umap as up

from tools import plot_3D, plot_the_PCA_interval, plot_clusters
RANDOM_STATE = 42

os.environ["MKL_THREADING_LAYER"] = "GNU"

# %% [markdown]
# ### Dimesion redusing

# %%
X = sparse.load_npz("../datasets/clusterization/train.npz")
M, N = X.shape
# масштабируем
scaler = RobustScaler(with_centering=False)
X_scaled = scaler.fit_transform(X)
# PCA
pca_new = PCA(n_components=40)
X_embedded_pca = pca_new.fit_transform(X_scaled)

# %% [markdown]
# ### Clusterization
# Здесь используются параметры подобранные через gridsearch

# %% [markdown]
# AgglomerativeClustering
#
# {'linkage': 'ward', 'metric': 'euclidean', 'n_clusters': 40} = 0.07
# {'linkage': 'average', 'metric': 'cosine', 'n_clusters': 40} = 0.075
# {'linkage': 'average', 'metric': 'cosine', 'n_clusters': 4} = 0.1
# {'linkage': 'average', 'metric': 'cosine', 'n_clusters': 6} = 0.09
# {'linkage': 'single', 'metric': 'cosine', 'n_clusters': 4} = 0

# %%
from sklearn.cluster import AgglomerativeClustering


plot_clusters(X_embedded_pca, AgglomerativeClustering, [], {'linkage': 'average', 'metric': 'cosine', 'n_clusters': 3})
# Out:
# silhouette_score: 0.27576453029977094
# Данные по классам: {np.int64(0): np.int64(8654), np.int64(1): np.int64(10152), np.int64(2): np.int64(2194)}
# Clusters found by AgglomerativeClustering
# Clustering took 29.33 s

# %% [markdown]
# GaussianMixture
#
# {'covariance_type': 'tied', 'init_params': 'k-means++', 'n_components': 14} = 0.005
# {'covariance_type': 'tied', 'init_params': 'k-means++', 'n_components': 17} = 0.013
# {'covariance_type': 'tied', 'init_params': 'k-means++', 'n_components': 20} = 0.025
# {'covariance_type': 'tied', 'init_params': 'k-means++', 'n_components': 23} = 0.025
# {'covariance_type': 'tied', 'init_params': 'k-means++', 'n_components': 50} = 0.065
# {'covariance_type': 'tied', 'init_params': 'k-means++', 'n_components': 70} = 0.06

# %%
from sklearn.mixture import GaussianMixture

plot_clusters(X_scaled.toarray(), GaussianMixture, [], {'covariance_type': 'tied', 'init_params': 'k-means++', 'n_components': 50})
# Out:
# silhouette_score: -0.03630793541316681
# Данные по классам: {np.int64(0): np.int64(8), np.int64(1): np.int64(6974), np.int64(2): np.int64(358), np.int64(3): np.int64(2620), np.int64(4): np.int64(1050), np.int64(5): np.int64(1111), np.int64(6): np.int64(8364), np.int64(7): np.int64(79), np.int64(8): np.int64(223), np.int64(9): np.int64(213)}
# Clusters found by GaussianMixture
# Clustering took 459.26 s

# %%
from sklearn.cluster import KMeans
RANDOM_SEED = 42

plot_clusters(X_embedded_pca, KMeans, [], {'n_clusters': 3, 'random_state': RANDOM_SEED, 'n_init': 20})
# Out:
# silhouette_score: 0.34124545073027723
# Данные по классам: {np.int32(0): np.int64(17326), np.int32(1): np.int64(1001), np.int32(2): np.int64(1247), np.int32(3): np.int64(1426)}
# Clusters found by KMeans
# Clustering took 7.77 s

# %%
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import Normalizer

norm = Normalizer()
X_embedded_pca_norm = norm.fit_transform(X_embedded_pca)


plot_clusters(X_embedded_pca_norm, SpectralClustering, [], {'n_clusters': 3})
# Out:
# c:\Users\user_1\miniforge3\envs\ipynb_VK\Lib\site-packages\threadpoolctl.py:1226: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# silhouette_score: 0.43164696253591495
# Данные по классам: {np.int32(0): np.int64(9967), np.int32(1): np.int64(1802), np.int32(2): np.int64(9231)}
# Clusters found by SpectralClustering
# Clustering took 282.17 s
